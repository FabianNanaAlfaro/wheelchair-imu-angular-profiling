# %% [markdown]
# # Cleaned iSen processing workflow
#
# Cleaned public-facing notebook for the wheelchair IMU angular profiling workflow.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.signal import butter, filtfilt

# %%
def butterworth_lowpass(data, cutoff_hz=6.0, fs=100.0, order=4):
    nyquist = 0.5 * fs
    b, a = butter(order, cutoff_hz / nyquist, btype='low')
    return filtfilt(b, a, np.asarray(data, dtype=float))

# %%
# Set a local folder containing de-identified iSen CSV files.
input_folder = Path('../data')
output_folder = Path('../outputs/python_exploration')
output_folder.mkdir(parents=True, exist_ok=True)

# %%
# This notebook is intended for exploratory inspection only.
# Final manuscript descriptors should be generated using the corrected MATLAB workflow.
print('Ready to process de-identified iSen CSV files.')
